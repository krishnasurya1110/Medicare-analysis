# %%
import pandas as pd
pd.set_option('display.max_columns', None)

df = pd.read_csv('n_physicians_updated.csv')
df.head()
# Out:
#           NPI   LastName FirstName Credentials Gender      City RUCA_category  \
# 0  1003000126  Enkeshafi   Ardalan          MD      M  Bethesda         Urban
# 1  1003000126  Enkeshafi   Ardalan          MD      M  Bethesda         Urban
# 2  1003000126  Enkeshafi   Ardalan          MD      M  Bethesda         Urban
# 3  1003000126  Enkeshafi   Ardalan          MD      M  Bethesda         Urban
# 4  1003000480  Rothchild     Kevin          MD      M    Aurora         Urban
#
#                 Type                BETOS_level           BETOS_desc  \
# 0  Internal Medicine  Durable Medical Equipment  Oxygen and supplies
# 1  Internal Medicine  Durable Medical Equipment  Oxygen and supplies
# 2  Internal Medicine  Durable Medical Equipment          Wheelchairs
# 3  Internal Medicine  Durable Medical Equipment          Wheelchairs
# 4    General Surgery  Durable Medical Equipment  Oxygen and supplies
#
#   Suplr_Rentl_Ind  Avg_Suplr_Sbmtd_Chrg  Avg_Suplr_Mdcr_Alowd_Amt  \
# ...

# %%
df.columns
# Out:
# Index(['NPI', 'LastName', 'FirstName', 'Credentials', 'Gender', 'City',
#        'RUCA_category', 'Type', 'BETOS_level', 'BETOS_desc', 'Suplr_Rentl_Ind',
#        'Avg_Suplr_Sbmtd_Chrg', 'Avg_Suplr_Mdcr_Alowd_Amt',
#        'Avg_Suplr_Mdcr_Pymt_Amt', 'Avg_Suplr_Mdcr_Stdzd_Amt', 'State'],
#       dtype='object')

# %%
df = df[['NPI', 'LastName', 'FirstName', 'Credentials', 'Gender', 'City', 'State', 'RUCA_category', 'Type']]
phy = df.groupby('NPI').first().reset_index()
phy.head()
# Out:
#           NPI   LastName  FirstName Credentials Gender        City  \
# 0  1003000126  Enkeshafi    Ardalan          MD      M    Bethesda
# 1  1003000480  Rothchild      Kevin          MD      M      Aurora
# 2  1003000522    Weigand  Frederick          MD      M     Deltona
# 3  1003000530   Semonche     Amanda          DO      F  Quakertown
# 4  1003000902     Lohano   Jaivanti          MD      F  Louisville
#
#           State RUCA_category               Type
# 0      Maryland         Urban  Internal Medicine
# 1      Colorado         Urban    General Surgery
# 2       Florida         Urban    Family Practice
# 3  Pennsylvania         Urban  Internal Medicine
# 4      Kentucky         Urban    Family Practice

# %%
phy.to_csv('n_physicians_only.csv', index=False)
